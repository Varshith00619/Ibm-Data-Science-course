# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# <h2>In this notebook, Data Science Tools and Ecosystem are summarized.</h2>

# %% [markdown]
# <h4>Some of the popular languages that Data Scientists use are:</h4>

# %% [markdown]
# <ol>
#     <li>python</li>
#     <li>R</li>
#     <li>SQL</li>
#     <li>Hadoop</li>
# </ol>

# %% [markdown]
# <h4>Some of the commonly used libraries used by Data Scientists include:</h4>

# %% [markdown]
# <ol>
#     <li>numpy</li>
#     <li>pandas</li>
#     <li>matplotlib</li>
# </ol>

# %% [markdown]
# <table boder:"1">
#     <tr>
#         <th>tools in data science </th>
#     </tr>
#     <tr>
#         <td>Jupyter Notebook </td>
#     </tr>
#     <tr>
#         <td>RStudio</td>
#     </tr>
#     <tr>
#         <td>Apache Zeppelin </td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
(3*4)+5
# Out:
# 17

# %%
a=int(input("enter a number"))
b=(a/60)
print(b)
# Out:
# enter a number 200
# 3.3333333333333335

# %% [markdown]
# <ul>
#     <li>python</li>
#     <li>R</li>
#     <li>SQL</li>
# </ul>

# %% [markdown]
# <H1>AUTHOUR NAME </H1>
# <H2>M.VENKATA VARSHITH REDDY</H2>
